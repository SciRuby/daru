# %% [markdown]
# ## Categorical data visualization with GnuplotRB

# %%
require 'gnuplotrb'
require 'daru'
include GnuplotRB
# Out:
# "if(window['d3'] === undefined ||\n   window['Nyaplot'] === undefined){\n    var path = {\"d3\":\"https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min\",\"downloadable\":\"https://cdn.rawgit.com/domitry/d3-downloadable/master/d3-downloadable\"};\n\n\n\n    var shim = {\"d3\":{\"exports\":\"d3\"},\"downloadable\":{\"exports\":\"downloadable\"}};\n\n    require.config({paths: path, shim:shim});\n\n\nrequire(['d3'], function(d3){window['d3']=d3;console.log('finished loading d3');require(['downloadable'], function(downloadable){window['downloadable']=downloadable;console.log('finished loading downloadable');\n\n\tvar script = d3.select(\"head\")\n\t    .append(\"script\")\n\t    .attr(\"src\", \"https://cdn.rawgit.com/domitry/Nyaplotjs/master/release/nyaplot.js\")\n\t    .attr(\"async\", true);\n\n\tscript[0][0].onload = script[0][0].onreadystatechange = function(){\n\n\n\t    var event = document.createEvent(\"HTMLEvents\");\n\t    event.initEvent(\"load_nyaplot\",false,false);\n\t    window.dispatchEvent(event);\n\t    console.log('Finished loading Nyaplotjs');\n\n\t};\n\n\n});});\n}\n"
# Object

# %% [markdown]
# ### Plotting categorical vector

# %% [markdown]
# #### Bar graph of frequencies

# %%
dv = Daru::Vector.new [:a, :a, :a, :b, :b], type: :category
# Out:
# #<Daru::Vector(5)>
#    0   a
#    1   a
#    2   a
#    3   b
#    4   b

# %%
Plot.new [dv.frequencies, with: :hist], xrange: -1..2, yrange: 0..10
# Out:
# #<GnuplotRB::Plot:0x00000001b26208 @options=Hamster::Hash[:xrange => -1..2, :yrange => 0..10], @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x00000001b25f88 @type=:datablock, @data=#<GnuplotRB::Datablock:0x00000001b25b28 @stored_in_file=false, @data="\"a\" 3\n\"b\" 2\n">, @options=Hamster::Hash[:title => nil, :with => :hist, :using => "2:xtic(1)"]>], @cmd="plot ">

# %% [markdown]
# #### Bar graph of percentage

# %%
Plot.new [dv.frequencies(:percentage), with: 'histogram'], xrange: -1..2, yrange: 0..100
# Out:
# #<GnuplotRB::Plot:0x00000003056790 @options=Hamster::Hash[:xrange => -1..2, :yrange => 0..100], @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x00000003056588 @type=:datablock, @data=#<GnuplotRB::Datablock:0x00000003056290 @stored_in_file=false, @data="\"a\" 60.0\n\"b\" 40.0\n">, @options=Hamster::Hash[:title => nil, :with => "histogram", :using => "2:xtic(1)"]>], @cmd="plot ">

# %% [markdown]
# ### Plotting dataframes with categorical data

# %%
df = Daru::DataFrame.new({
  x: [1, 2, 3, 4, 5, 6, 7, 8],
  y: [3, 2, 3, 5, 6, 1, 2, 3],
  cat: ['III', 'II', 'I', 'I', 'II', 'I', 'III', 'III']
})
df[:cat] = df[:cat].to_category categories: ['I', 'II', 'III']
df[:cat].type
# Out:
# :category

# %%
dfs = df.split_by_category :cat
# The line below is because of this issue: https://github.com/SciRuby/gnuplotrb/issues/8
dfs.each { |df| df.index = df.nrows.times.to_a }
###
Plot.new(
  *dfs.map { |df| [df, using: 'x:y'] }, xrange: 0..10, yrange: 0..10
)
# Out:
# #<GnuplotRB::Plot:0x0000000310b5c8 @options=Hamster::Hash[:xrange => 0..10, :yrange => 0..10], @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x0000000310b398 @type=:datablock, @data=#<GnuplotRB::Datablock:0x0000000310ab50 @stored_in_file=false, @data="0 3 3\n1 4 5\n2 6 1\n">, @options=Hamster::Hash[:title => "I", :using => "2:3"]>, #<GnuplotRB::Dataset:0x000000031091d8 @type=:datablock, @data=#<GnuplotRB::Datablock:0x000000031089e0 @stored_in_file=false, @data="0 2 2\n1 5 6\n">, @options=Hamster::Hash[:title => "II", :using => "2:3"]>, #<GnuplotRB::Dataset:0x000000031137a0 @type=:datablock, @data=#<GnuplotRB::Datablock:0x00000003112fa8 @stored_in_file=false, @data="0 1 3\n1 7 2\n2 8 3\n">, @options=Hamster::Hash[:title => "III", :using => "2:3"]>], @cmd="plot ">

# %%
df = Daru::DataFrame.new({
  x: [3, 3, 3],
  y: [1, 2, 3]
})
Plot.new [df, using: '2:3'], yrange: -5..5
# Out:
# #<GnuplotRB::Plot:0x00000001d9db30 @options=Hamster::Hash[:yrange => -5..5], @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x00000001d9cc58 @type=:datablock, @data=#<GnuplotRB::Datablock:0x000000031dbcc8 @stored_in_file=false, @data="0 3 1\n1 3 2\n2 3 3\n">, @options=Hamster::Hash[:title => nil, :using => "2:3"]>], @cmd="plot ">

# %%
df = Daru::DataFrame.new({
  x: [3, 3, 3],
  y: [1, 2, 3]
  }, index: [1, 5, 2])
Plot.new [df, using: '2:3'], yrange: -5..5
# Out:
# #<GnuplotRB::Plot:0x000000033520e8 @options=Hamster::Hash[:yrange => -5..5], @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x00000003351f08 @type=:datablock, @data=#<GnuplotRB::Datablock:0x00000003351a08 @stored_in_file=false, @data="1 3 1\n5 3 1\n2 3 3\n">, @options=Hamster::Hash[:title => nil, :using => "2:3"]>], @cmd="plot ">
